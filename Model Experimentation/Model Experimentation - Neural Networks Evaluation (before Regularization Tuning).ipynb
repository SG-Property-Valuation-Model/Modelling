# %% [markdown]
# # Setting Up Environment

# %%
import math, os, re, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2-Layer Neural Network Architectures

# %%
df_2nn = pd.read_csv('../input/bt4222-2-layer-neural-networks/two_layer_nn_results.csv')
df_2nn.sort_values(by='eval_rmse', ascending=True, inplace=True)

df_2nn.head(20)
# Out:
#      n_layer1  n_layer2  batch_norm  drop_rate   train_rmse    eval_rmse  \
# 12        512       512        True        0.2   973.707947  1036.633301
# 31        512       512       False        0.2   999.002686  1042.361816
# 43        256       512        True        0.3  1038.881958  1079.101196
# 24        256       512       False        0.2  1052.207764  1097.484009
# 88        512       512        True        0.5  1068.266479  1100.527100
# 37        512       256       False        0.2  1062.349121  1104.322021
# 62        256       512       False        0.3  1072.285156  1105.117920
# 69        512       512       False        0.3  1069.958496  1109.469727
# 50        512       512        True        0.3  1075.687866  1121.267578
# 87        256       256        True        0.5  1116.078735  1139.392822
# 5         256       512        True        0.2  1086.639404  1145.093506
# 30        256       256       False        0.2  1122.104248  1152.170654
# ...

# %% [markdown]
# # 3-Layer Neural Network Architectures

# %%
df_3nn = pd.read_csv('../input/bt4222-3-layer-neural-networks-updated/three_layer_nn_results.csv')
df_3nn.sort_values(by='eval_rmse', ascending=True, inplace=True)

df_3nn.head(20)
# Out:
#     n_layer1  n_layer2  n_layer3      batch_norm  drop_rate   train_rmse  \
# 4        128       256       512    (True, True)        0.5   974.705017
# 22       512       512       512    (True, True)        0.5   961.532654
# 15       256       512       256    (True, True)        0.5   997.049683
# 21       256       256       256    (True, True)        0.5  1009.992065
# 20       128       128       128    (True, True)        0.5  1067.704590
# 91       512       512       512  (False, False)        0.5  1046.210693
# 38       256       512       256   (True, False)        0.5  1064.150391
# 9        512       256       128    (True, True)        0.5  1098.353882
# 8        256       128        64    (True, True)        0.5  1141.700439
# 45       512       512       512   (True, False)        0.5  1121.754761
# 27       128       256       512   (True, False)        0.5  1152.747925
# 44       256       256       256   (True, False)        0.5  1172.093262
# ...
