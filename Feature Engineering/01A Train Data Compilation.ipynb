# %% [markdown]
# # Preprocessing of Train Station Datasets

# %%
import pandas as pd
import geopandas
import json, math, os, re, requests, time
import datetime
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)

# %%
# Navigate to the directory containing final_dataset.csv
os.chdir('C:/Users/Mindy/Documents/BT4222/Group Project/Primary Datasets/')

# %% [markdown]
# # Section 1: MRT Opening Dates

# %%
# Dataset of MRT Opening
mrt_opening = pd.read_excel('mrt_openingDates.xlsx', header = None)
mrt_opening.columns = ['STN_NO', 'STN_PREFIX', 'OPEN_DATE']
mrt_opening.index = mrt_opening.index + 1
mrt_opening.head()
# Out:
#        STN_NO     STN_PREFIX  OPEN_DATE
# 1  NS1  EW24     Jurong East 1990-03-10
# 2        NS2     Bukit Batok 1990-03-10
# 3        NS3    Bukit Gombak 1990-03-10
# 4         NS4  Choa Chu Kang 1990-03-10
# 5        NS5         Yew Tee 1996-02-10

# %%
mrt_opening.shape
# Out:
# (152, 3)

# %%
mrt_opening.dtypes
# Out:
# STN_NO                object
# STN_PREFIX            object
# OPEN_DATE     datetime64[ns]
# dtype: object

# %%
# Cleanin STN_NO so that only the first value is taken
mrt_opening['cleaned_STN_NO'] = mrt_opening['STN_NO'].apply(lambda x: str(x).strip().split('\xa0')[0])

# Dropping duplicated instances (ie. interchanges)
mrt_opening = mrt_opening[mrt_opening['cleaned_STN_NO'].duplicated(keep='last') == False]
mrt_opening.head()

# Editing instances where STN_NAME = 'Botanic Gardens • Kebun Bunga'
mrt_opening.loc[mrt_opening['STN_PREFIX'].str.contains('Botanic Gardens'), 'STN_PREFIX'] = 'Botanic Gardens'

# %%
len(mrt_opening['cleaned_STN_NO'].unique())
# Out:
# 145

# %%
mrt_opening.head()
# Out:
#        STN_NO     STN_PREFIX  OPEN_DATE cleaned_STN_NO
# 1  NS1  EW24     Jurong East 1990-03-10            NS1
# 2        NS2     Bukit Batok 1990-03-10            NS2
# 3        NS3    Bukit Gombak 1990-03-10            NS3
# 4         NS4  Choa Chu Kang 1990-03-10            NS4
# 5        NS5         Yew Tee 1996-02-10            NS5

# %% [markdown]
# # Section 2: LRT Opening Dates

# %%
lrt_opening = pd.read_excel('lrt_openingDates.xlsx', header = None)
lrt_opening.columns = ['STN_NO', 'STN_PREFIX', 'OPEN_DATE', 'CLOSE_DATE']
lrt_opening.index = lrt_opening.index + 1
lrt_opening.head()
# Out:
#        STN_NO     STN_PREFIX  OPEN_DATE CLOSE_DATE
# 1   BP1  NS4   Choa Chu Kang 1999-11-06        NaT
# 2        BP2      South View 1999-11-06        NaT
# 3        BP3       Keat Hong 1999-11-06        NaT
# 4        BP4       Teck Whye 1999-11-06        NaT
# 5        BP5         Phoenix 1999-11-06        NaT

# %%
lrt_opening.dtypes
# Out:
# STN_NO                object
# STN_PREFIX            object
# OPEN_DATE     datetime64[ns]
# CLOSE_DATE    datetime64[ns]
# dtype: object

# %%
# Cleanin STN_NO so that only the first value is taken
lrt_opening['cleaned_STN_NO'] = lrt_opening['STN_NO'].apply(lambda x: str(x).strip().split('\xa0')[0])

# Correcting cleaned_STN_NO for Sengkang station
lrt_opening.loc[lrt_opening['cleaned_STN_NO'] == 'NE16','cleaned_STN_NO'] = 'STC'

# %% [markdown]
# # Section 3: Train Stations

# %%
def prep_train_station_df(train_stations): 
    
    # Leaving out Bukit Brown Station CC18  and Teck Lee Station PW2 
    # since they are not yet open (ie. opening dates are TBA)
    train_stations = train_stations[train_stations['STN_NO'] != 'CC18'] 
    train_stations = train_stations[train_stations['STN_NO'] != 'PW2']

    # Altering COLOR column for all LRT stations from 'OTHERS' to 'LRT' 
    train_stations.loc[train_stations['STN_NAME'].str.contains('LRT'), 'COLOR'] = 'LRT'

    # Altering COLOR columns for all stations along the Thompson East Coast line from 'OTHERS' to 'BROWN'
    train_stations.loc[train_stations['STN_NO'].str.contains('TE'), 'COLOR'] = 'BROWN'

    # Altering COLOR columns for all CE stations from 'OTHERS' to 'YELLOW'
    train_stations.loc[train_stations['STN_NO'].str.contains('CE'), 'COLOR'] = 'YELLOW'

    # Altering COLOR columns for all CG stations from 'OTHERS' to 'GREEN'
    train_stations.loc[train_stations['STN_NO'].str.contains('CG'), 'COLOR'] = 'GREEN'

    """
    # Converting train_stations from DataFrame object in GeoDataFrame
    train_station_gdf = geopandas.GeoDataFrame(train_stations, 
                                               geometry=geopandas.points_from_xy(train_stations['Longitude'], train_stations['Latitude']),
                                               crs={"init":"EPSG:4326"})

    # Converting CRS so that we can calculate distances in meters instead of degrees
    train_station_gdf = train_station_gdf.to_crs({"init": "EPSG:3857"})
    """
    return train_stations

# %%
train_stations = pd.read_csv('mrtsg.csv')
train_stations = prep_train_station_df(train_stations)

# Separating MRT stations from LRT stations
lrt = train_stations[train_stations['COLOR'] == 'LRT']
mrt = train_stations[train_stations['COLOR'] != 'LRT']

# %%
mrt.head()
# Out:
#    OBJECTID                STN_NAME STN_NO           X           Y  Latitude  \
# 0        12   ADMIRALTY MRT STATION   NS10  24402.1063  46918.1131  1.440585
# 1        16    ALJUNIED MRT STATION    EW9  33518.6049  33190.0020  1.316433
# 2        33  ANG MO KIO MRT STATION   NS16  29807.2655  39105.7720  1.369933
# 5       153     BARTLEY MRT STATION   CC12  33168.3039  36108.7003  1.342828
# 6       115    BAYFRONT MRT STATION    CE1  30867.0093  29368.6250  1.281874
#
#     Longitude   COLOR
# 0  103.800998     RED
# 1  103.882893   GREEN
# 2  103.849553     RED
# 5  103.879746  YELLOW
# 6  103.859073  YELLOW

# %% [markdown]
# # Section 4: Combining MRT Datasets

# %%
# Checking that these dataframes are of the same length
len(mrt['STN_NO'].values) == len(mrt_opening['STN_NO'].values)
# Out:
# True

# %%
# Check that the stations within these 2 dataframes are a 1-to-1 match
# There should be no output if it is indeed a 1-to-1 match
for station in mrt['STN_NO'].values: 
    if (station not in mrt_opening['cleaned_STN_NO'].values): 
            print(station)
            
print('---------------')
            
for station in mrt_opening['cleaned_STN_NO'].values: 
    if (station not in mrt['STN_NO'].values): 
            print(station)
# Out:
# ---------------

# %%
mrt = mrt.join(mrt_opening.set_index('cleaned_STN_NO'), on = 'STN_NO', lsuffix='_station', rsuffix='_opening')
mrt = mrt.drop('STN_NO_opening', axis = 1)
mrt.rename(columns = {'STN_NO_station': 'STN_NO'}, inplace = True)

# %%
# Double verifying correctness of join
mrt['NAME_VERIFIED'] = mrt.apply(lambda x: x['STN_PREFIX'].upper() in x['STN_NAME'], axis = 1)
mrt['NAME_VERIFIED'].value_counts()
# Out:
# True    145
# Name: NAME_VERIFIED, dtype: int64

# %% [markdown]
# # Section 5: Combining LRT Datasets

# %%
# Checking that these dataframes are of the same length
len(lrt['STN_NO'].values) == len(lrt_opening['STN_NO'].values)
# Out:
# True

# %%
# Check that the stations within these 2 dataframes are a 1-to-1 match
# There should be no output if it is indeed a 1-to-1 match
for station in lrt['STN_NO'].values: 
    if (station not in lrt_opening['cleaned_STN_NO'].values): 
            print(station)
            
print('---------------')
            
for station in lrt_opening['cleaned_STN_NO'].values: 
    if (station not in lrt['STN_NO'].values): 
            print(station)
# Out:
# ---------------

# %%
lrt = lrt.join(lrt_opening.set_index('cleaned_STN_NO'), on = 'STN_NO', lsuffix='_station', rsuffix='_opening')
lrt = lrt.drop('STN_NO_opening', axis = 1)
lrt.rename(columns = {'STN_NO_station': 'STN_NO'}, inplace = True)

# %%
# Double verifying correctness of join
lrt['NAME_VERIFIED'] = lrt.apply(lambda x: x['STN_PREFIX'].upper() in x['STN_NAME'], axis = 1)
lrt['NAME_VERIFIED'].value_counts()
# Out:
# True    42
# Name: NAME_VERIFIED, dtype: int64

# %% [markdown]
# # Section 6: Final Train Stations Dataset

# %%
mrt['CLOSE_DATE'] = datetime.datetime(2100, 12, 31)
lrt.loc[lrt['CLOSE_DATE'].isnull() == True, 'CLOSE_DATE'] = datetime.datetime(2100, 3, 31)
mrt = mrt.append(lrt, ignore_index=True)

# %%
# Checking for duplicates
mrt[mrt.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [OBJECTID, STN_NAME, STN_NO, X, Y, Latitude, Longitude, COLOR, STN_PREFIX, OPEN_DATE, NAME_VERIFIED, CLOSE_DATE]
# Index: []

# %%
# Dropping unneccesary columns
mrt = mrt.drop(['STN_PREFIX', 'NAME_VERIFIED'], axis = 1)
mrt
# Out:
#      OBJECTID                       STN_NAME STN_NO           X           Y  \
# 0          12          ADMIRALTY MRT STATION   NS10  24402.1063  46918.1131
# 1          16           ALJUNIED MRT STATION    EW9  33518.6049  33190.0020
# 2          33         ANG MO KIO MRT STATION   NS16  29807.2655  39105.7720
# 3         153            BARTLEY MRT STATION   CC12  33168.3039  36108.7003
# 4         115           BAYFRONT MRT STATION    CE1  30867.0093  29368.6250
# 5         115           BAYFRONT MRT STATION   DT16  30867.0093  29368.6250
# 6         140       BEAUTY WORLD MRT STATION    DT5  21598.1665  35931.2359
# 7          37              BEDOK MRT STATION    EW5  38757.9520  34024.7048
# 8         143        BEDOK NORTH MRT STATION   DT29  37421.7438  35214.6804
# 9         149    BEDOK RESERVOIR MRT STATION   DT30  39008.3132  35421.0409
# 10        100          BENCOOLEN MRT STATION   DT21  29899.2575  31247.3368
# 11         99          BENDEMEER MRT STATION   DT23  31300.8084  32884.7382
# 12        109             BISHAN MRT STATION   CC15  29762.3507  37046.3699
# 13        158             BISHAN MRT STATION   NS17  29649.8988  36994.4330
# 14        178          BOON KENG MRT STATION    NE9  31157.0712  33517.6089
# 15         34           BOON LAY MRT STATION   EW27  13837.9827  35641.9191
# 16        185    BOTANIC GARDENS MRT STATION   CC19  25959.4046  33817.7525
# 17        159    BOTANIC GARDENS MRT STATION    DT9  26087.2663  33852.4484
# 18        182           BRADDELL MRT STATION   NS18  29500.0972  35848.0687
# 19         93         BRAS BASAH MRT STATION    CC2  29930.7674  31025.9016
# 20        183           BUANGKOK MRT STATION   NE15  34655.3132  40537.2069
# 21        103              BUGIS MRT STATION   DT14  30620.8769  31323.2495
# 22        111              BUGIS MRT STATION   EW12  30491.5648  31424.3503
# 23         32        BUKIT BATOK MRT STATION    NS2  18679.3541  36795.0141
# 24         35       BUKIT GOMBAK MRT STATION    NS3  18938.3305  37870.6512
# 25        171      BUKIT PANJANG MRT STATION    DT1  20011.3981  40108.6838
# 26        124        BUONA VISTA MRT STATION   CC22  23251.7611  32090.7692
# 27         28        BUONA VISTA MRT STATION   EW21  23200.3600  32167.2655
# 28        127          CALDECOTT MRT STATION   CC17  28691.2451  35538.7680
# 29        192           CANBERRA MRT STATION   NS12  27597.3086  47196.1838
# 30        172             CASHEW MRT STATION    DT2  20362.9591  39043.5835
# 31        180     CHANGI AIRPORT MRT STATION    CG2  45254.8614  37711.0150
# 32        132          CHINATOWN MRT STATION   DT19  29238.9683  29686.5359
# 33        131          CHINATOWN MRT STATION    NE4  29124.9585  29643.4786
# 34          2     CHINESE GARDEN MRT STATION   EW25  16790.7466  36056.3019
# 35         19      CHOA CHU KANG MRT STATION    NS4  18097.9271  40811.9589
# 36         95          CITY HALL MRT STATION   EW13  30144.2851  30591.8478
# 37         95          CITY HALL MRT STATION   NS25  30144.2851  30591.8478
# 38        157        CLARKE QUAY MRT STATION    NE5  29473.1249  30088.7038
# 39         15           CLEMENTI MRT STATION   EW23  20430.0600  33026.6075
# 40          8       COMMONWEALTH MRT STATION   EW20  24103.2523  31642.6034
# 41        154             DAKOTA MRT STATION    CC8  34159.2741  32299.8905
# 42        165        DHOBY GHAUT MRT STATION    CC1  29437.9401  31244.9618
# 43        164        DHOBY GHAUT MRT STATION    NE6  29354.3681  31340.3479
# 44        144        DHOBY GHAUT MRT STATION   NS24  29424.1448  31229.3143
# 45         29              DOVER MRT STATION   EW22  21914.5509  32634.1186
# 46        123           DOWNTOWN MRT STATION   DT17  30172.6259  29100.1876
# 47        125          ESPLANADE MRT STATION    CC3  30469.0566  30634.4621
# 48          1              EUNOS MRT STATION    EW7  35782.9553  33560.0776
# 49         18               EXPO MRT STATION    CG1  42270.6232  35193.6223
# 50        122               EXPO MRT STATION   DT35  42362.7103  35285.6654
# 51        151        FARRER PARK MRT STATION    NE8  30321.3596  32739.6107
# 52        121        FARRER ROAD MRT STATION   CC20  25136.2263  33309.1617
# 53        120       FORT CANNING MRT STATION   DT20  29225.2834  30541.2748
# 54         98      GEYLANG BAHRU MRT STATION   DT24  32293.7994  33750.9518
# 55         23         GUL CIRCLE MRT STATION   EW30   8772.8552  33530.3675
# 56        101       HARBOURFRONT MRT STATION   CC29  26678.3445  27555.0595
# 57        101       HARBOURFRONT MRT STATION    NE1  26678.3445  27555.0595
# 58        161      HAW PAR VILLA MRT STATION   CC25  22267.5675  29442.5730
# 59        136           HILLVIEW MRT STATION    DT3  20666.0676  38266.7899
# 60        187    HOLLAND VILLAGE MRT STATION   CC21  23868.1442  32681.5744
# 61        177            HOUGANG MRT STATION   NE14  34572.8759  39256.1311
# 62        114        JALAN BESAR MRT STATION   DT22  30466.0301  31970.4313
# 63         38           JOO KOON MRT STATION   EW29  10756.3543  34438.2764
# 64         20        JURONG EAST MRT STATION   EW24  17869.0806  35038.9472
# 65         20        JURONG EAST MRT STATION    NS1  17869.0806  35038.9472
# 66        141         KAKI BUKIT MRT STATION   DT28  36362.4224  35239.5458
# 67         26            KALLANG MRT STATION   EW10  32236.6038  32643.3302
# 68         31          KEMBANGAN MRT STATION    EW6  36862.1237  33699.3568
# 69        104         KENT RIDGE MRT STATION   CC24  22581.5421  30650.0972
# 70          3             KHATIB MRT STATION   NS14  27962.3108  44352.5680
# 71        137   KING ALBERT PARK MRT STATION    DT6  22489.8451  35316.6349
# 72        119              KOVAN MRT STATION   NE13  33758.7578  38027.2795
# 73          4             KRANJI MRT STATION    NS7  20081.6974  45214.5479
# 74        130      LABRADOR PARK MRT STATION   CC27  24619.0578  28313.6298
# 75         39           LAKESIDE MRT STATION   EW26  15494.5171  36267.1619
# 76        163           LAVENDER MRT STATION   EW11  31284.2589  32186.4342
# 77        168       LITTLE INDIA MRT STATION   DT12  29698.9692  32168.8611
# 78        169       LITTLE INDIA MRT STATION    NE7  29817.1982  32124.8312
# 79        162       LORONG CHUAN MRT STATION   CC14  31431.4054  37079.9444
# 80         94         MACPHERSON MRT STATION   CC10  34340.0124  34286.1222
# 81        105         MACPHERSON MRT STATION   DT26  34235.7966  34256.4317
# 82        129         MARINA BAY MRT STATION    CE2  30423.4296  28735.7843
# 83        128         MARINA BAY MRT STATION   NS27  30368.2057  28766.3819
# 84        150  MARINA SOUTH PIER MRT STATION   NS28  31287.7063  28203.4939
# 85         36          MARSILING MRT STATION    NS8  21406.6874  46025.7686
# 86        160          MARYMOUNT MRT STATION   CC16  28679.3688  36758.7136
# 87        138             MATTAR MRT STATION   DT25  33556.5834  34344.8585
# 88        118        MOUNTBATTEN MRT STATION    CC7  33476.5634  32058.7418
# 89        133             NEWTON MRT STATION   DT11  28499.9628  32877.5173
# 90        191             NEWTON MRT STATION   NS21  28519.3616  32735.2072
# 91        126     NICOLL HIGHWAY MRT STATION    CC5  31374.1708  31347.1516
# 92        147             NOVENA MRT STATION   NS20  29169.3298  33633.1535
# 93        108          ONE-NORTH MRT STATION   CC23  22896.0731  31346.4085
# 94        113            ORCHARD MRT STATION   NS22  27880.1256  31813.1134
# 95        188        OUTRAM PARK MRT STATION   EW16  28646.3739  29316.7727
# 96        156        OUTRAM PARK MRT STATION    NE3  28696.2602  29135.3820
# 97        155      PASIR PANJANG MRT STATION   CC26  23329.2647  28742.7658
# 98         14          PASIR RIS MRT STATION    EW1  40903.7716  39443.3983
# 99        152         PAYA LEBAR MRT STATION    CC9  34550.5756  33300.3402
# 100         9         PAYA LEBAR MRT STATION    EW8  34648.6773  33375.7341
# 101         7            PIONEER MRT STATION   EW28  12864.9592  35529.4973
# 102       176       POTONG PASIR MRT STATION   NE10  31977.1677  34842.7289
# 103       184          PROMENADE MRT STATION    CC4  31080.6082  30623.0174
# 147        47      BUKIT PANJANG LRT STATION    BP6  20175.9353  39987.9068
# 148        70          CHENG LIM LRT STATION    SW1  34730.4628  42018.8886
# 149        65      CHOA CHU KANG LRT STATION    BP1  18121.6052  40753.8693
# 150        83        COMPASSVALE LRT STATION    SE1  35475.5631  41821.5783
# 151        55         CORAL EDGE LRT STATION    PE3  36820.8455  41757.0642
# 152        59               COVE LRT STATION    PE1  36084.2293  42351.1334
# 153        58              DAMAI LRT STATION    PE7  36378.1828  43009.3794
# 154        48              FAJAR LRT STATION   BP10  21043.4356  40718.8826
# 155        44            FARMWAY LRT STATION    SW2  34230.5193  42117.5716
# 156        73           FERNVALE LRT STATION    SW5  32784.2264  41533.2289
# 157        62           JELAPANG LRT STATION   BP12  20341.7491  40960.2020
# 158        54           KADALOOR LRT STATION    PE5  37255.4884  42384.6619
# 159        68            KANGKAR LRT STATION    SE4  35662.7300  40658.9821
# 160        57          KEAT HONG LRT STATION    BP3  18622.5727  40064.5711
# 161        45             KUPANG LRT STATION    SW3  33334.8164  42232.8408
# 162        67              LAYAR LRT STATION    SW6  33198.3233  41554.6829
# 163        69           MERIDIAN LRT STATION    PE2  36416.7925  42089.0886
# 164        52             NIBONG LRT STATION    PW5  35455.6286  43743.0854
# 165        42              OASIS LRT STATION    PE6  36837.1178  42683.4018
# 166        76            PENDING LRT STATION    BP8  21094.7812  39792.4936
# 167        63              PETIR LRT STATION    BP7  20582.7273  39970.2513
# 168        90            PHOENIX LRT STATION    BP5  19621.7772  40066.3155
# 169        50            PUNGGOL LRT STATION    PTC  35689.1390  43004.9202
# 170        71      PUNGGOL POINT LRT STATION    PW3  36160.8276  44293.5561
# 171        89           RANGGUNG LRT STATION    SE5  35108.5942  40687.1255
# 172        46            RENJONG LRT STATION    SW8  34367.9437  40962.4782
# 173        60            RIVIERA LRT STATION    PE4  37219.8293  41825.1114
# 174        82             RUMBIA LRT STATION    SE2  36085.5526  41487.1568
# 175        43            SAM KEE LRT STATION    PW1  35958.3967  43493.4470
# 176        51           SAMUDERA LRT STATION    PW4  35660.6597  44188.8482
# 177        91              SEGAR LRT STATION   BP11  20908.7670  41078.4025
# 178        92           SENGKANG LRT STATION    STC  34913.5879  41502.6997
# 179        61              SENJA LRT STATION   BP13  20104.0139  40516.7226
# 180        53           SOO TECK LRT STATION    PW7  35110.1988  42993.1699
# 181        66         SOUTH VIEW LRT STATION    BP2  18203.7243  40252.0686
# 182        72             SUMANG LRT STATION    PW6  35260.2918  43365.1308
# 183        64          TECK WHYE LRT STATION    BP4  19140.8000  39852.4608
# 184        85  TEN MILE JUNCTION LRT STATION   BP14  19856.1189  40254.5250
# 185        56           THANGGAM LRT STATION    SW4  32709.2689  42133.9003
# 186        74           TONGKANG LRT STATION    SW7  33845.4132  41252.6183
#
#      Latitude   Longitude   COLOR  OPEN_DATE CLOSE_DATE
# 0    1.440585  103.800998     RED 1996-02-10 2100-12-31
# 1    1.316433  103.882893   GREEN 1989-11-04 2100-12-31
# 2    1.369933  103.849553     RED 1987-11-07 2100-12-31
# 3    1.342828  103.879746  YELLOW 2009-05-28 2100-12-31
# 4    1.281874  103.859073  YELLOW 2012-01-14 2100-12-31
# 150  1.394493  103.900473     LRT 2003-01-18 2100-03-31
# 151  1.393909  103.912557     LRT 2005-01-29 2100-03-31
# 152  1.399282  103.905940     LRT 2005-01-29 2100-03-31
# 153  1.405235  103.908581     LRT 2011-06-20 2100-03-31
# 154  1.384521  103.770827     LRT 1999-11-06 2100-03-31
# 155  1.397170  103.889288     LRT 2007-11-15 2100-03-31
# 156  1.391886  103.876296     LRT 2005-01-29 2100-03-31
# 157  1.386703  103.764523     LRT 1999-11-06 2100-03-31
# 158  1.399585  103.916462     LRT 2005-01-29 2100-03-31
# 159  1.383979  103.902154     LRT 2003-01-18 2100-03-31
# 160  1.378603  103.749080     LRT 1999-11-06 2100-03-31
# 161  1.398213  103.881242     LRT 2015-06-27 2100-03-31
# 162  1.392080  103.880016     LRT 2005-01-29 2100-03-31
# 163  1.396912  103.908928     LRT 2005-01-29 2100-03-31
# 164  1.411870  103.900294     LRT 2014-06-29 2100-03-31
# 165  1.402287  103.912704     LRT 2007-06-15 2100-03-31
# 166  1.376143  103.771288     LRT 1999-11-06 2100-03-31
# 167  1.377750  103.766688     LRT 1999-11-06 2100-03-31
# 168  1.378619  103.758056     LRT 1999-11-06 2100-03-31
# 169  1.405195  103.902391     LRT 2005-01-29 2100-03-31
# 170  1.416849  103.906628     LRT 2016-12-29 2100-03-31
# 171  1.384234  103.897176     LRT 2003-01-18 2100-03-31
# 172  1.386724  103.890523     LRT 2005-01-29 2100-03-31
# 173  1.394524  103.916141     LRT 2005-01-29 2100-03-31
# 174  1.391468  103.905952     LRT 2003-01-18 2100-03-31
# 175  1.409613  103.904810     LRT 2016-02-29 2100-03-31
# 176  1.415902  103.902135     LRT 2017-03-31 2100-03-31
# 177  1.387772  103.769617     LRT 1999-11-06 2100-03-31
# 178  1.391609  103.895424     LRT 2003-01-18 2100-03-31
# 179  1.382692  103.762388     LRT 1999-11-06 2100-03-31
# 180  1.405089  103.897190     LRT 2014-06-29 2100-03-31
# 181  1.380298  103.745317     LRT 1999-11-06 2100-03-31
# 182  1.408452  103.898539     LRT 2014-06-29 2100-03-31
# 183  1.376685  103.753735     LRT 1999-11-06 2100-03-31
# 184  1.380321  103.760161     LRT 1999-11-06 2019-01-13
# 185  1.397318  103.875623     LRT 2005-01-29 2100-03-31
# 186  1.389348  103.885829     LRT 2005-01-29 2100-03-31

# %%
# Checking for null values
mrt.isnull().any()
# Out:
# OBJECTID      False
# STN_NAME      False
# STN_NO        False
# X             False
# Y             False
# Latitude      False
# Longitude     False
# COLOR         False
# OPEN_DATE     False
# CLOSE_DATE    False
# dtype: bool

# %%
mrt['COLOR'].value_counts()

# ___ LRT Stations ___
# Historically, there has been a totoal of 41 LRT stations opened. 
# Ten Mile Junction is the only Lrt station that has ceased operations

# ___ BROWN Line ___
# The Thomson East Coast Line cuurently only has 3 stations in operation when verifying with the mrt map published

# ___ Other Lines ___
# The number of train stations for the rest of the lines were verified through a quick google search
# Out:
# LRT       42
# GREEN     35
# BLUE      34
# YELLOW    30
# RED       27
# PURPLE    16
# BROWN      3
# Name: COLOR, dtype: int64

# %% [markdown]
# # Saving Dataset

# %%
mrt.to_csv('train_stations_data.csv')
